# %% [markdown]
# <a href="https://colab.research.google.com/github/rpbilang/ML-Project/blob/main/Exercise_2_KNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Learning Team Exercise 2 - KNN Imple
# Identify your own dataset and implement a classifier or regressor prediction model. Follow the steps that we have discussed in class:
#
# 1. Choose a Dataset. Select a dataset for classification and another for regression.
# 2. Identify the feature and target variable X and y
# 3. Split the Data. Divide the data into a training set and a test set (typically 70/30 split).
# 4. Run and fit the model using an initial `K`.
# 5. Evaluate the performance of your model.
#
# Create a summary after runnning the models discussing the following:
# - Data Description: Summarize the dataset
# - Target Variable: State the target variable
# - Accuracy Metrics: List the metrics used and your model's performance.
# - Optimal Model: Describe how you chose the optimal 'k' and any patterns noted.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# #### 1. Dataset Loading

# %%
#Import Libraries here
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import mean_squared_error, r2_score
import matplotlib.pyplot as plt

# %%
#Import dataset here
heart_all = pd.read_csv('/content/drive/MyDrive/AI/heart_failure_clinical_records_dataset.csv')
heart_all.head()
# Out:
#     age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0  75.0        0                       582         0                 20
# 1  55.0        0                      7861         0                 38
# 2  65.0        0                       146         0                 20
# 3  50.0        1                       111         0                 20
# 4  65.0        1                       160         1                 20
#
#    high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# 0                    1  265000.00               1.9           130    1
# 1                    0  263358.03               1.1           136    1
# 2                    0  162000.00               1.3           129    1
# 3                    0  210000.00               1.9           137    1
# 4                    0  327000.00               2.7           116    0
#
#    smoking  time  DEATH_EVENT
# 0        0     4            1
# 1        0     6            1
# 2        1     7            1
# 3        0     7            1
# 4        0     8            1

# %%
#Check the summary statistics of the data
heart_all.describe()
# Out:
#               age     anaemia  creatinine_phosphokinase    diabetes  \
# count  299.000000  299.000000                299.000000  299.000000
# mean    60.833893    0.431438                581.839465    0.418060
# std     11.894809    0.496107                970.287881    0.494067
# min     40.000000    0.000000                 23.000000    0.000000
# 25%     51.000000    0.000000                116.500000    0.000000
# 50%     60.000000    0.000000                250.000000    0.000000
# 75%     70.000000    1.000000                582.000000    1.000000
# max     95.000000    1.000000               7861.000000    1.000000
#
#        ejection_fraction  high_blood_pressure      platelets  \
# count         299.000000           299.000000     299.000000
# mean           38.083612             0.351171  263358.029264
# std            11.834841             0.478136   97804.236869
# min            14.000000             0.000000   25100.000000
# 25%            30.000000             0.000000  212500.000000
# 50%            38.000000             0.000000  262000.000000
# 75%            45.000000             1.000000  303500.000000
# max            80.000000             1.000000  850000.000000
#
#        serum_creatinine  serum_sodium         sex    smoking        time  \
# count         299.00000    299.000000  299.000000  299.00000  299.000000
# mean            1.39388    136.625418    0.648829    0.32107  130.260870
# std             1.03451      4.412477    0.478136    0.46767   77.614208
# min             0.50000    113.000000    0.000000    0.00000    4.000000
# 25%             0.90000    134.000000    0.000000    0.00000   73.000000
# 50%             1.10000    137.000000    1.000000    0.00000  115.000000
# 75%             1.40000    140.000000    1.000000    1.00000  203.000000
# max             9.40000    148.000000    1.000000    1.00000  285.000000
#
#        DEATH_EVENT
# count    299.00000
# mean       0.32107
# std        0.46767
# min        0.00000
# 25%        0.00000
# 50%        0.00000
# 75%        1.00000
# max        1.00000

# %% [markdown]
# The dataset was taken from a Kaggle Competition

# %% [markdown]
# #### 2. Identify X and y

# %%
# Your Code Here

# %% [markdown]
# #### 3. Split the data into train and test sets.

# %%
# Your Code Here

# %% [markdown]
# #### 4. Run and fit the model

# %%
# Your Code Here

# %% [markdown]
# #### 5. Evaluate the performance of your model

# %%
# Your Code Here

# %% [markdown]
# #### Summary Report
#
# ***Your answer here***
